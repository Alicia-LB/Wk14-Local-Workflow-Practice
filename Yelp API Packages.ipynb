# %% [markdown]
# # Yelp API Packages
#
# ## Import libraries

# %%
import json
with open ('/Users/alicia/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#import yelpapi 

from yelpapi import YelpAPI

#create instance

yelp_api = YelpAPI(login['api-key'], timeout_s = 5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 436

# %%
import pandas as pd
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
#
#                          name  \
# 0           Faidley's Seafood
# 1  Thames Street Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1199
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2762
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
#
#                                        coordinates transactions price  \
# 0  {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
# 1   {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
#
#                                             location         phone  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 1  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
#
#     display_phone     distance
# 0  (410) 727-4898  1349.560720
# 1  (443) 449-7726  2090.712792

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                        alias               name  \
# 0  NQu0GgFMcAB6ucmhSNpcSQ   phillips-seafood-baltimore   Phillips Seafood
# 1  Kh1XJP54vra02w7vS5rRhg  clock-restoration-baltimore  CLOCK Restoration
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/yZFOdQ...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Cquy0W...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/phillips-seafood-balt...          1534
# 1  https://www.yelp.com/biz/clock-restoration-bal...            35
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.0
# 1  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 39.286385925645, 'longitude': -76...  [pickup, delivery]
# 1     {'latitude': 39.28807, 'longitude': -76.61196}  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '601 E Pratt St', 'address2': '',...  +14106856600
# 1   NaN  {'address1': '31 S Calvert St', 'address2': 'F...  +14106857428
#
#     display_phone     distance
# 0  (410) 685-6600  1089.215502
# 1  (410) 685-7428   975.367255

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
#
#                          name  \
# 0           Faidley's Seafood
# 1  Thames Street Oyster House
# 2         Miss Shirley's Cafe
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/9FsOyV...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1199
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2762
# 2  https://www.yelp.com/biz/miss-shirleys-cafe-ba...          2977
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 2  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
#
#                                          coordinates transactions price  \
# 0    {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
# 1     {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
# 2  {'latitude': 39.2870995, 'longitude': -76.6053...   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 1  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
# 2  {'address1': '750 E Pratt St', 'address2': '',...  +14105285373
#
#     display_phone     distance
# 0  (410) 727-4898  1349.560720
# 1  (443) 449-7726  2090.712792
# 2  (410) 528-5373  1028.736468
#                         id                            alias  \
# 37  t0EA_fXewpQWfzWMrpNjIw      peters-pour-house-baltimore
# 38  WgruUR88nIv4Gy8NFm59KQ          shore-seafood-baltimore
# 39  GOvVNYe2DwjGzwdVJIKw1Q  wicked-sisters-tavern-baltimore
#
#                      name                                          image_url  \
# 37     Peter's Pour House  https://s3-media3.fl.yelpcdn.com/bphoto/A5kRmG...
# 38          Shore Seafood  https://s3-media1.fl.yelpcdn.com/bphoto/9OKYfz...
# 39  Wicked Sisters Tavern  https://s3-media2.fl.yelpcdn.com/bphoto/XdSbMU...
#
#     is_closed                                                url  \
# 37      False  https://www.yelp.com/biz/peters-pour-house-bal...
# 38      False  https://www.yelp.com/biz/shore-seafood-baltimo...
# 39      False  https://www.yelp.com/biz/wicked-sisters-tavern...
#
#     review_count                                         categories  rating  \
# 37           231  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 38            17  [{'alias': 'seafoodmarkets', 'title': 'Seafood...     4.0
# 39           583  [{'alias': 'tradamerican', 'title': 'American ...     4.0
#
#                                           coordinates        transactions  \
# 37     {'latitude': 39.28841, 'longitude': -76.61299}  [pickup, delivery]
# 38  {'latitude': 39.297649115324, 'longitude': -76...          [delivery]
# 39  {'latitude': 39.3350187678809, 'longitude': -7...  [pickup, delivery]
#
#    price                                           location         phone  \
# 37    $$  {'address1': '111 Mercer St', 'address2': None...  +14105395818
# 38     $  {'address1': '601 N Chester St', 'address2': '...  +14106757705
# 39    $$  {'address1': '3845 Falls Rd', 'address2': '', ...  +14108780884
#
#      display_phone     distance
# 37  (410) 539-5818   978.567909
# 38  (410) 675-7705  1727.500589
# 39  (410) 878-0884  4974.443762
